# %% [markdown]
# <a href="https://colab.research.google.com/github/as3fn/Coursera_Capstone/blob/master/IBM_Capstone_week3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Part 1**
#
# In this part the address of Ontareo is scraped from the internet and incoded into a dataframe.

# %%
from bs4 import BeautifulSoup
import requests
wiki='https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M'
file=requests.get(wiki)
sop=BeautifulSoup(file.content,'html.parser')
table=sop.find('table',class_="wikitable sortable")


type(table)
# Out:
# bs4.element.Tag

# %%
import re
tb=[]
for row in table.find_all('tr'):
    for cell in row.find_all('td'):
        #tb.append(re.match(r'\w+[\']?\s?\w+',cell.text).group())
        tb.append(cell.text.replace('\n',''))


tb[:6]
# Out:
# ['M1A', 'Not assigned', 'Not assigned', 'M2A', 'Not assigned', 'Not assigned']

# %%
from collections import defaultdict
final_table=defaultdict(list)

for i,h in enumerate(table.find_all('th')):
    final_table[h.text.replace('\n','')]=tb[i::3][:-1] #the parsere produced \n at the end of the strings at the last location in the row

# %%
import pandas as pd

final_table=pd.DataFrame(final_table)
final_table.head()
# Out:
#   Postcode           Borough     Neighbourhood
# 0      M1A      Not assigned      Not assigned
# 1      M2A      Not assigned      Not assigned
# 2      M3A        North York         Parkwoods
# 3      M4A        North York  Victoria Village
# 4      M5A  Downtown Toronto      Harbourfront

# %%
final_table[(final_table['Borough']!='Not assigned')& (final_table['Neighbourhood']=='Not assigned')]
# Out:
#   Postcode       Borough Neighbourhood
# 9      M9A  Queen's Park  Not assigned

# %%
mask=(final_table['Borough']=='Not assigned')
final_table.drop(final_table[mask].index,inplace=True)

final_table[final_table['Neighbourhood']=='Not assigned']['Neighbourhood'].index
final_table.loc[9,'Neighbourhood']=final_table.loc[9,'Borough']


final_table=final_table.groupby(['Postcode','Borough']).agg(lambda x:','.join(x))
final_table.reset_index(inplace=True)

final_table.head()
# Out:
#   Postcode      Borough                         Neighbourhood
# 0      M1B  Scarborough                         Rouge,Malvern
# 1      M1C  Scarborough  Highland Creek,Rouge Hill,Port Union
# 2      M1E  Scarborough       Guildwood,Morningside,West Hill
# 3      M1G  Scarborough                                Woburn
# 4      M1H  Scarborough                             Cedarbrae

# %% [markdown]
# **Part 2.**
#
# In this part the location information about each postcode is incoded and the two dataframes are meged together

# %%
# !wget -q -O 'locationdata.csv' https://cocl.us/Geospatial_data
print('Data downloaded!')
# Out:
# Data downloaded!

# %%
locs=pd.read_csv('locationdata.csv')
locs.head()
# Out:
#   Postal Code   Latitude  Longitude
# 0         M1B  43.806686 -79.194353
# 1         M1C  43.784535 -79.160497
# 2         M1E  43.763573 -79.188711
# 3         M1G  43.770992 -79.216917
# 4         M1H  43.773136 -79.239476

# %%
merged=final_table.merge(locs,left_on='Postcode',right_on='Postal Code', how='left')
merged.drop('Postal Code',axis=1,inplace=True)
merged.head()
# Out:
#   Postcode      Borough  ...   Latitude  Longitude
# 0      M1B  Scarborough  ...  43.806686 -79.194353
# 1      M1C  Scarborough  ...  43.784535 -79.160497
# 2      M1E  Scarborough  ...  43.763573 -79.188711
# 3      M1G  Scarborough  ...  43.770992 -79.216917
# 4      M1H  Scarborough  ...  43.773136 -79.239476
#
# [5 rows x 5 columns]

# %%
from geopy.geocoders import Nominatim

# %%
address = 'Toronto, Ontario'

geolocator = Nominatim(user_agent="ny_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Manhattan are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of Manhattan are 43.653963, -79.387207.

# %%
import folium

# %%
toronto=merged[merged['Borough'].str.contains('Toronto')]
toronto.head()
# Out:
#    Postcode          Borough  ...   Latitude  Longitude
# 37      M4E     East Toronto  ...  43.676357 -79.293031
# 41      M4K     East Toronto  ...  43.679557 -79.352188
# 42      M4L     East Toronto  ...  43.668999 -79.315572
# 43      M4M     East Toronto  ...  43.659526 -79.340923
# 44      M4N  Central Toronto  ...  43.728020 -79.388790
#
# [5 rows x 5 columns]

# %% [markdown]
# **Part 3.**
#
# In this part the locations of toronto are parsed form the ontareo data and grouped togther in a map, then venus of different neighborhoods are shown for each location and clustered to divide the neighborhoods into different segments depending on the type of venus in the area.

# %% [markdown]
# **Mapping Toronto with its Neighbourhoods and different parts of the city**
#
# Choosing only Neighbourhoods that are located only in Toronto, we plot every Neighbourhood as a point with its information as a interavtive popup in the following map.

# %%
toronto_map= folium.Map(location=[latitude,longitude],zoom_start=12)

for lat, lng, neig,borog in zip(toronto['Latitude'], toronto['Longitude'], toronto['Neighbourhood'],toronto['Borough']):
    label = '{}, {}'.format(neig, borog)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(toronto_map)  
    
toronto_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# **Foursquare**
# After finding the locations and ploting them on the map, we use the Foursquare API to find relative information about each location ( venus availabe, ratings ..etc)

# %%
CLIENT_ID = '34EHRE4OXKRURVUISQ5WYOWED0CW5LEKS5MAQCTIYEMX2GVS' # your Foursquare ID
CLIENT_SECRET = '2NVR4UDMB0QQIBUWLPLRLWW5WG3XBQJDSCKG51LBDVPUR2SR' # your Foursquare Secret
VERSION = '20190111' # Foursquare API version
LIMIT=100
redius=500
print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: 34EHRE4OXKRURVUISQ5WYOWED0CW5LEKS5MAQCTIYEMX2GVS
# CLIENT_SECRET:2NVR4UDMB0QQIBUWLPLRLWW5WG3XBQJDSCKG51LBDVPUR2SR

# %%
def getNearbyVenues(names, latitudes, longitudes, radius=500):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighborhood', 
                  'Neighborhood Latitude', 
                  'Neighborhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# %%
# type your answer here

toronto_venues = getNearbyVenues(names=toronto['Neighbourhood'],
                                   latitudes=toronto['Latitude'],
                                   longitudes=toronto['Longitude']
                                  )
# Out:
# The Beaches
# The Danforth West,Riverdale
# The Beaches West,India Bazaar
# Studio District
# Lawrence Park
# Davisville North
# North Toronto West
# Davisville
# Moore Park,Summerhill East
# Deer Park,Forest Hill SE,Rathnelly,South Hill,Summerhill West
# Rosedale
# Cabbagetown,St. James Town
# Church and Wellesley
# Harbourfront
# Ryerson,Garden District
# St. James Town
# Berczy Park
# Central Bay Street
# Adelaide,King,Richmond
# Harbourfront East,Toronto Islands,Union Station
# Design Exchange,Toronto Dominion Centre
# Commerce Court,Victoria Hotel
# Roselawn
# Forest Hill North,Forest Hill West
# The Annex,North Midtown,Yorkville
# Harbord,University of Toronto
# Chinatown,Grange Park,Kensington Market
# CN Tower,Bathurst Quay,Island airport,Harbourfront West,King and Spadina,Railway Lands,South Niagara
# Stn A PO Boxes 25 The Esplanade
# First Canadian Place,Underground city
# Christie
# Dovercourt Village,Dufferin
# Little Portugal,Trinity
# ...

# %%
toronto_venues.head()
# Out:
#   Neighborhood  Neighborhood Latitude  ...  Venue Longitude     Venue Category
# 0  The Beaches              43.676357  ...       -79.293942              Trail
# 1  The Beaches              43.676357  ...       -79.297734  Health Food Store
# 2  The Beaches              43.676357  ...       -79.297215                Pub
# 3  The Beaches              43.676357  ...       -79.292869       Neighborhood
# 4  The Beaches              43.676357  ...       -79.298167   Asian Restaurant
#
# [5 rows x 7 columns]

# %%
toronto_venues.groupby('Neighborhood').count()
# Out:
#                                                     Neighborhood Latitude  ...  Venue Category
# Neighborhood                                                               ...
# Adelaide,King,Richmond                                                100  ...             100
# Berczy Park                                                            56  ...              56
# Brockton,Exhibition Place,Parkdale Village                             22  ...              22
# Business Reply Mail Processing Centre 969 Eastern                      16  ...              16
# CN Tower,Bathurst Quay,Island airport,Harbourfr...                     17  ...              17
# Cabbagetown,St. James Town                                             42  ...              42
# Central Bay Street                                                     87  ...              87
# Chinatown,Grange Park,Kensington Market                                90  ...              90
# ...

# %%
print('There are {} uniques categories.'.format(len(toronto_venues['Venue Category'].unique())))
# Out:
# There are 235 uniques categories.

# %%
# one hot encoding
toronto_onehot = pd.get_dummies(toronto_venues[['Venue Category']], prefix="", prefix_sep="")

# add neighborhood column back to dataframe
toronto_onehot['Neighborhood'] = toronto_venues['Neighborhood'] 

# move neighborhood column to the first column
# fixed_columns = ['Neighborhood'] + list(toronto_onehot.columns[:-1])
# toronto_onehot = toronto_onehot[fixed_columns]

# %%
col=list(toronto_onehot.columns)
col.remove('Neighborhood')
toronto_onehot=toronto_onehot[['Neighborhood']+col]
toronto_onehot
# Out:
#                                            Neighborhood  ...  Yoga Studio
# 0                                           The Beaches  ...            0
# 1                                           The Beaches  ...            0
# 2                                           The Beaches  ...            0
# 3                                           The Beaches  ...            0
# 4                                           The Beaches  ...            0
# ...                                                 ...  ...          ...
# 1705  Business Reply Mail Processing Centre 969 Eastern  ...            0
# 1706  Business Reply Mail Processing Centre 969 Eastern  ...            0
# 1707  Business Reply Mail Processing Centre 969 Eastern  ...            1
# 1708  Business Reply Mail Processing Centre 969 Eastern  ...            0
# 1709  Business Reply Mail Processing Centre 969 Eastern  ...            0
#
# [1710 rows x 235 columns]

# %%
toronto_grouped = toronto_onehot.groupby('Neighborhood').mean().reset_index()
toronto_grouped.head()
# Out:
#                                         Neighborhood  ...  Yoga Studio
# 0                             Adelaide,King,Richmond  ...       0.0000
# 1                                        Berczy Park  ...       0.0000
# 2         Brockton,Exhibition Place,Parkdale Village  ...       0.0000
# 3  Business Reply Mail Processing Centre 969 Eastern  ...       0.0625
# 4  CN Tower,Bathurst Quay,Island airport,Harbourf...  ...       0.0000
#
# [5 rows x 235 columns]

# %%
def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    
    return row_categories_sorted.index.values[0:num_top_venues]

# %%
import numpy as np
num_top_venues = 10

indicators = ['st', 'nd', 'rd']

# create columns according to number of top venues
columns = ['Neighborhood']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))

# create a new dataframe
neighborhoods_venues_sorted = pd.DataFrame(columns=columns)
neighborhoods_venues_sorted['Neighborhood'] = toronto_grouped['Neighborhood']

for ind in np.arange(toronto_grouped.shape[0]):
    neighborhoods_venues_sorted.iloc[ind, 1:] = return_most_common_venues(toronto_grouped.iloc[ind, :], num_top_venues)

neighborhoods_venues_sorted.head()
# Out:
#                                         Neighborhood  ... 10th Most Common Venue
# 0                             Adelaide,King,Richmond  ...                  Hotel
# 1                                        Berczy Park  ...                 Bistro
# 2         Brockton,Exhibition Place,Parkdale Village  ...     Italian Restaurant
# 3  Business Reply Mail Processing Centre 969 Eastern  ...            Yoga Studio
# 4  CN Tower,Bathurst Quay,Island airport,Harbourf...  ...       Sculpture Garden
#
# [5 rows x 11 columns]

# %%
from sklearn.cluster import KMeans
kclusters=5
toronto_grouped_clustering = toronto_grouped.drop('Neighborhood', 1)

# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(toronto_grouped_clustering)

# check cluster labels generated for each row in the dataframe
kmeans.labels_[0:10]
# Out:
# array([1, 1, 1, 1, 0, 1, 1, 1, 1, 1], dtype=int32)

# %%
neighborhoods_venues_sorted.insert(0, 'Cluster Labels', kmeans.labels_)
# Out:
#    Cluster Labels  ... 10th Most Common Venue
# 0               1  ...                  Hotel
# 1               1  ...                 Bistro
# 2               1  ...     Italian Restaurant
# 3               1  ...            Yoga Studio
# 4               0  ...       Sculpture Garden
#
# [5 rows x 12 columns]

# %%
# add clustering labels


toronto_merged = toronto

# merge toronto_grouped with toronto_data to add latitude/longitude for each neighborhood
toronto_merged = toronto_merged.join(neighborhoods_venues_sorted.set_index('Neighborhood'), on='Neighbourhood')

toronto_merged.head() # check the last columns!
# Out:
#    Postcode  ... 10th Most Common Venue
# 37      M4E  ...            Yoga Studio
# 41      M4K  ...              Juice Bar
# 42      M4L  ...   Fast Food Restaurant
# 43      M4M  ...         Sandwich Place
# 44      M4N  ...    Dumpling Restaurant
#
# [5 rows x 16 columns]

# %%
import matplotlib.cm as cm
import matplotlib.colors as colors

# %%
map_clusters = folium.Map(location=[latitude, longitude], zoom_start=11)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(toronto_merged['Latitude'], toronto_merged['Longitude'], toronto_merged['Neighbourhood'], toronto_merged['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
toronto_merged.loc[toronto_merged['Cluster Labels'] == 0, toronto_merged.columns[[1] + list(range(5, toronto_merged.shape[1]))]]
# Out:
#              Borough  ...  10th Most Common Venue
# 68  Downtown Toronto  ...        Sculpture Garden
#
# [1 rows x 12 columns]

# %%
toronto_merged.loc[toronto_merged['Cluster Labels'] == 1, toronto_merged.columns[[1] + list(range(5, toronto_merged.shape[1]))]]
# Out:
#              Borough  ...         10th Most Common Venue
# 37      East Toronto  ...                    Yoga Studio
# 41      East Toronto  ...                      Juice Bar
# 42      East Toronto  ...           Fast Food Restaurant
# 43      East Toronto  ...                 Sandwich Place
# 45   Central Toronto  ...                     Donut Shop
# 46   Central Toronto  ...                           Café
# 47   Central Toronto  ...                        Brewery
# 49   Central Toronto  ...                    Supermarket
# 51  Downtown Toronto  ...           Caribbean Restaurant
# 52  Downtown Toronto  ...       Mediterranean Restaurant
# 53  Downtown Toronto  ...                     Shoe Store
# 54  Downtown Toronto  ...            Japanese Restaurant
# 55  Downtown Toronto  ...                 Cosmetics Shop
# 56  Downtown Toronto  ...                         Bistro
# 57  Downtown Toronto  ...                         Bakery
# ...

# %%
toronto_merged.loc[toronto_merged['Cluster Labels'] == 2, toronto_merged.columns[[1] + list(range(5, toronto_merged.shape[1]))]]
# Out:
#             Borough  ...  10th Most Common Venue
# 48  Central Toronto  ...                 Dog Run
#
# [1 rows x 12 columns]

# %%
toronto_merged.loc[toronto_merged['Cluster Labels'] == 3, toronto_merged.columns[[1] + list(range(5, toronto_merged.shape[1]))]]
# Out:
#              Borough  ...  10th Most Common Venue
# 44   Central Toronto  ...     Dumpling Restaurant
# 50  Downtown Toronto  ...        Doner Restaurant
# 64   Central Toronto  ...              Donut Shop
#
# [3 rows x 12 columns]

# %%
toronto_merged.loc[toronto_merged['Cluster Labels'] == 4, toronto_merged.columns[[1] + list(range(5, toronto_merged.shape[1]))]]
# Out:
#             Borough  ...  10th Most Common Venue
# 63  Central Toronto  ...        Doner Restaurant
#
# [1 rows x 12 columns]
